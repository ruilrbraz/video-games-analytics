# %%
import pandas as pd
import sqlalchemy
import requests
import time
import os
from dotenv import load_dotenv

load_dotenv()

DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")
RAWG_API_KEY = os.getenv("RAWG_API_KEY")

if not all([DB_USER, DB_PASS, DB_HOST, DB_NAME, RAWG_API_KEY]):
    print("Error: One or more environment variables are missing.")
    print("Please check your .env file.")
    exit()

DB_CONNECTION_STRING = f'mysql+mysqlconnector://{DB_USER}:{DB_PASS}@{DB_HOST}/{DB_NAME}'
RAWG_API_URL_BASE = "https://api.rawg.io/api/publishers"

# %%
def enrich_publisher_data():
    """
    Connects to the MySQL DB, reads Publishers, calls the RAWG API
    (first to search, then to get details) to find the founding year,
    and updates the table.
    """
    try:
        engine = sqlalchemy.create_engine(DB_CONNECTION_STRING)
        
        with engine.connect() as conn:
            print("Connection successful!")
            
        print("Reading list of publishers from MySQL database...")
        query = "SELECT publisher_id, publisher_name FROM Publishers WHERE founding_year IS NULL"
        df_publishers = pd.read_sql(query, engine)
        
        if df_publishers.empty:
            print("All publishers are already enriched. No work to do.")
            return

        print(f"Found {len(df_publishers)} publishers to enrich...")
        
        with engine.connect() as conn:
            for index, row in df_publishers.iterrows():
                publisher_id = row['publisher_id']
                publisher_name = row['publisher_name']
                
                if publisher_name == 'Unknown':
                    print("Skipping 'Unknown' publisher...")
                    continue
                
                try:
                    search_params = {'key': RAWG_API_KEY, 'search': publisher_name}
                    response = requests.get(RAWG_API_URL_BASE, params=search_params)
                    response.raise_for_status() 
                    search_data = response.json()
                    
                    if search_data['count'] > 0:
                        # Get the ID from the first search result
                        publisher_api_id = search_data['results'][0]['id']
                        
                        # STEP 2: Call the DETAIL ENDPOINT using that ID
                        detail_url = f"{RAWG_API_URL_BASE}/{publisher_api_id}"
                        detail_params = {'key': RAWG_API_KEY}
                        
                        detail_response = requests.get(detail_url, params=detail_params)
                        detail_response.raise_for_status()
                        detail_data = detail_response.json()

                        # STEP 3: Parse the (correct) detail data
                        if 'year_start' in detail_data and detail_data['year_start']:
                            founding_year = detail_data['year_start']
                            
                            update_statement = sqlalchemy.text(
                                "UPDATE Publishers SET founding_year = :year WHERE publisher_id = :id"
                            )
                            with conn.begin():
                                conn.execute(update_statement, {"year": founding_year, "id": publisher_id})
                            
                            print(f"SUCCESS: Updated '{publisher_name}' (ID: {publisher_id}) with founding year: {founding_year}")
                        else:
                            print(f"INFO: Found publisher '{publisher_name}', but 'year_start' key is missing on its detail page.")
                    else:
                        print(f"INFO: No API results found for '{publisher_name}' (ID: {publisher_id})")

                except requests.RequestException as e:
                    print(f"WARN: API request failed for '{publisher_name}'. Error: {e}")
                
                # Be kind to the API and wait
                time.sleep(1) 
                
        print("\n--- API Enrichment Complete! ---")

    except sqlalchemy.exc.OperationalError as e:
        print(f"Error: Could not connect to the MySQL database. Access Denied.")
        print("Please double-check your DB_USER and DB_PASS in the .env file.")
    except Exception as e:
        print(f"An error occurred: {e}")

# --- Main execution ---
if __name__ == "__main__":
    enrich_publisher_data()
# Out:
# Connection successful!
# Reading list of publishers from MySQL database...
# Found 581 publishers to enrich...
# INFO: Found publisher 'Nintendo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Microsoft Game Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Take-Two Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sony Computer Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Activision', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ubisoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Bethesda Softworks', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Electronic Arts', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sega', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SquareSoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Atari', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '505 Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Capcom', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'GT Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Konami Digital Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Square Enix', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sony Computer Entertainment Europe', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Virgin Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'LucasArts', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Warner Bros. Interactive Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Universal Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Eidos Interactive', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'RedOctane' (ID: 23)
# INFO: Found publisher 'Vivendi Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Enix Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Namco Bandai Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Palcom', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hasbro Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'THQ', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Fox Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Acclaim Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'MTV Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Disney Interactive Studios', but 'year_start' key is missing on its detail page.
# Skipping 'Unknown' publisher...
# INFO: Found publisher 'Codemasters', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Majesco Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Red Orb', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Level 5', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Arena Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Midway Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'JVC', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Deep Silver', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NCSoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '989 Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'UEP Systems', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Parker Bros.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Maxis', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Imagic', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tecmo Koei', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ASCII Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Valve Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mindscape', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Infogrames', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Square', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Valve', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Banpresto', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hello Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'D3Publisher', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Activision Value', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Oxygen Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Red Storm Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Video System', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Global Star', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gotham Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Westwood Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'GungHo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Crave Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hudson Soft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Coleco', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Rising Star Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'TDK Mediactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ASC Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Accolade', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Zoo Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sony Online Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '3DO', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Natsume', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'RTL', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Alchemist', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Black Label Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SouthPeak Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Focus Home Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ocean', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Zoo Digital Publishing', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Psygnosis', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'City Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Empire Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Success', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Compile', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Russel', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Atlus', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mastertronic', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Slightly Mad Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Taito', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Agetec', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Microprose', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Play It', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'GSP', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tomy Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sammy Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Koch Media', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Game Factory', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Titus', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Marvelous Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Genki', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mojang', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'CTO SpA', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'TalonSoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Crystal Dynamics', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Square Enix ', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'mixi, Inc', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Pinnacle', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SCi', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Quelle', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Rage Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ubisoft Annecy', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Interplay', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Scholastic Inc.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mystique', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ChunSoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Square EA', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '20th Century Fox Video Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hudson Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Men-A-Vision', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nobilis', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Avanquest Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Big Ben Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nordic Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Touchstone', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Spike', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nippon Ichi Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sony Computer Entertainment America', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Jester Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'LEGO Media', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Quest', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Illusion Softworks', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tigervision', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Rocket Company', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Metro 3D', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mattel Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'IE Institute', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Funbox Media', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Rondomedia', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Universal Gamex', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ghostlight', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Wizard Video Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'BMG Interactive Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'PQube', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Trion Worlds', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Xseed Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Laguna', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Takara', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ignition Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kadokawa Shoten', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Enterbrain', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Imagineer', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'CPG Products', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'System 3 Arcade Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Aruze Corp', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Destineer', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gamebridge', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Midas Interactive Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Jaleco', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Answer Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Pack In Soft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'XS Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Rebellion', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ultravision', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Harmonix Music Systems', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Activision Blizzard', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Xplosiv', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Wanadoo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Telltale Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NovaLogic', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Epoch', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'BAM! Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'GameMill Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Knowledge Adventure', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tetris Online', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mastiff', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ESP', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'TYO' (ID: 182)
# INFO: Found publisher 'Telegames', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mud Duck Productions', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Screenlife', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Pioneer LDC', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Magical Company', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kemco', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mentor Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Human Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Data Age', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Electronic Arts Victor', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Jack of All Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Avanquest', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Black Bean Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '989 Sports', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Takara Tomy', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Media Rings', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Elf', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Starfish', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Zushi Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Jorudan', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Destination Software, Inc', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'New', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Brash Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kalypso Media', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ITT Family Games', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'Ackkstudios' (ID: 208)
# INFO: Found publisher 'PopCap Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Starpath Corp.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'BPS', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gathering of Developers', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NewKidCo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Marvelous Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Storm City Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'CokeM Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'P2 Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'CBS Electronics', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Home Entertainment Suppliers', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Magix', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Arc System Works', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Angel Studios', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'Wargaming.net' (ID: 223)
# INFO: Found publisher 'Playmates', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SNK Playmore', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hamster Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'From Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nippon Columbia', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nichibutsu', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Conspiracy Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hect', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mumbo Jumbo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'DTP Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Pacific Century Cyber Works', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Indie Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Liquid Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NEC', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Axela', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ArtDink', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sunsoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Little Orbit', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'FuRyu', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gust', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SNK', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NEC Interchannel', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nihon Falcom Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Xing Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ValuSoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Victor Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'American Softworks', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Falcom Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Detn8 Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Bomb', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nordcurrent', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Milestone S.r.l.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'AQ Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sears', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Seta Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'On Demand', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'CCP', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NCS', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Rebellion Developments', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Agatsuma Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gremlin Interactive Ltd', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Aspyr', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Compile Heart', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Culture Brain', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mad Catz', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Shogakukan', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Merscom LLC', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'JoWood Productions', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nippon Telenet', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'TDK Core', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kadokawa Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SSI', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Foreign Media Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Core Design Ltd.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'bitComposer Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Astragon', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Asylum Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Performance Designed Products', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'UFO Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Essential Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Adeline Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Funcom', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'PlayV', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Panther Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Blast! Entertainment Ltd', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Playlogic Game Factory', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'DSI Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Avalon Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Game Life', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Popcorn Arcade', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Aques', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'System 3', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Syscom', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Vir2L Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Vatical Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Neko Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'White Park Bay Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Vic Tokai', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Media Factory', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Daedalic', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Game Arts', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'The Adventure Company', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'EA Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Acquire', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Broccoli', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'General Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Paradox Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Yacht Club Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Imadio', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Swing! Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sony Music Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Aqua Plus', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Excalibur Publishing', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hip Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tripwire Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'DreamCatcher Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SCS Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Havas Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sting', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Idea Factory', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Telstar', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'U.S. Gold', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Funsta', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'DreamWorks Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Slitherine Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'MTO', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Graffiti', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tru Blu Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'DHM Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Crytek', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'FunSoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Data Design Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'SPS', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Moss', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'T&E Soft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NDA Productions', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Bigben Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Data East', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Idea Factory International', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Time Warner Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gainax Network Systems', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Daito', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'O3 Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'O-Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gameloft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Xicat Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Simon & Schuster Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Valcon Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'PopTop Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'TOHO', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'PM Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Bohemia Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Reef Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '5pb', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'HMH Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'inXile Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Cave', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Microids', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Paon', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'CDV Software Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Micro Cabin', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'GameTek', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Benesse', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Type-Moon', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Enjoy Gaming ltd.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Asmik Corp', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Interplay Productions', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Asmik Ace Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Image Epoch', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Phantom EFX', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Evolved Games', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'responDESIGN' (ID: 375)
# INFO: Found publisher 'Griffin International', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Culture Publishers', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hackberry', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Hearty Robin', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nippon Amuse', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Origin Systems', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Seventh Chord', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Abylight', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mitsui', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Insomniac Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Flight-Plan', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Milestone', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Glams', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Aksys Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Locus', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Warp', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Irem Software Engineering', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Myelin Media', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Global A Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Alternative Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mercury Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sunrise Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Elite', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Evolution Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Daedalic Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Edia', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Athena', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Aria', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tivola', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Happinet', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tommo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Altron', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Revolution Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Media Works', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Fortyfive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gamecock', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Imax', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '10TACLE Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Groove Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Pack-In-Video', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Crimson Cow', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'iWin', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Asgard', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ecole', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Yumedia', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ascaron Entertainment GmbH', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'HAL Laboratory', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Phenomedia', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Grand Prix Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'DigiCube', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Creative Core', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kaga Create', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'WayForward Technologies', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'LSP Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ASCII Media Works', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '1C Company', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Coconuts Japan', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Arika', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Marvel Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ertain', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Prototype', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Phantagram', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'The Learning Company', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'TechnoSoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'MLB.com', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Vap', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Misawa', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Yeti', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Dusenberry Martin Racing', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Navarre Corp', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Pow', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'MediaQuest', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Team17 Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Max Five', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Tradewest', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Comfort', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Milestone S.r.l', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Pony Canyon', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Riverhillsoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Summitsoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Playmore', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kool Kizz', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Monte Christo Multimedia', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'TopWare Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Legacy Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Cloud Imperium Games Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Flashpoint Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'CyberFront', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Alawar Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Societa', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Interchannel', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Experience Inc.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sonnet', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Virtual Play Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Zenrin', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Iceberg Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ivolgamus', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'MC2 Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '2D Boy', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Games Workshop', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kando Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Office Create', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Maximum Family Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Fields', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gearbox Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Princess Soft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Extreme Entertainment Group', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Big Fish Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Berkeley', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mamba Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Fuji', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'FuRyu Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Her Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'imageepoch Inc.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Just Flight', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kamui', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'ASK', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Cygames', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Introversion Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '49Games', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'KSS' (ID: 496)
# INFO: Found publisher 'dramatic create', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'TGL', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'KID', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Quinrose', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sold Out', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Encore', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'G.Rev', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sunflowers', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Headup Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Sweets', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kokopeli Digital Studios', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'id Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nexon', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'BushiRoad', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Devolver Digital', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Number None', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'Tryfirst' (ID: 513)
# INFO: Found publisher 'GN Software', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Yuke's', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Strategy First', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Lexicon Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Paon Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Kids Station', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Licensed 4U', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'GOA', but 'year_start' key is missing on its detail page.
# INFO: Found publisher '7G//AMES', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'King Records', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Minato Station', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Graphsim Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Easy Interactive', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gaga', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Yamasa Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Plenty', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Views', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Blue Byte', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'fonfun', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'NetRevo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Epic Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Quintet', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Focus Multimedia', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Phoenix Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Marvelous Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Dorart', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Codemasters Online', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Stainless Games', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Aerosoft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Imageworks', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Karin Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Technos Japan Corporation', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Masque Publishing', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Gakken', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'New World Computing', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mirai Shounen', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Datam Polystar', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'HuneX', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Visco', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Saurus', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Revolution (Japan)', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'Giza10' (ID: 555)
# INFO: Found publisher 'Alvion', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Giga', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Mycom', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Warashi', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'System Soft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'RED Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Lighthouse Interactive', but 'year_start' key is missing on its detail page.
# INFO: No API results found for 'Michaelsoft' (ID: 563)
# INFO: Found publisher 'Media Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Genterprise', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Interworks Unlimited, Inc.', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Inti Creates', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Boost On', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'EON Digital Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Nitroplus', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Naxat Soft', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Piacci', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Paradox Development', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Otomate', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ascaron Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Ongakukan', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Commseed', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'UIG Entertainment', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Takuyo', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Interchannel-Holon', but 'year_start' key is missing on its detail page.
# INFO: Found publisher 'Red Flagship', but 'year_start' key is missing on its detail page.
#
# --- API Enrichment Complete! ---
